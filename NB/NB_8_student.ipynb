# %% [markdown]
# # NB 8: Regression Modeling

# %% [markdown]
# ## Run Initial R Code

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "kmed", "openintro"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)
library(kmed)

email$spam <- factor(ifelse(email$spam == 0, "No", "Yes"))
email$to_multiple <- factor(ifelse(email$to_multiple == "0", "No", "Yes"))

# %% [markdown]
# ## Problem 1
#
# The `globalfood` data set contains 4 variables of 113 countries evaluating food insecurity in 2012. The outcome of interest is `affordability` (index of food affordability), and it will be explained by the predictors: `availability` (food availability index), `safety` (food quality and safety index), and `resilience` (natural resource and resilience index).

# %% [markdown]
# ### 1.1
#
# Fit a model explaining the outcome variable `affordability` and the predictor variable `availability`.

# %% [markdown]
# ### 1.2
#
# Interpret the slope for `availability`.

# %% [markdown]
# ### 1.3
#
# Fit a model explaining the outcome variable `affordability` and the predictor variable `availability` and  `safety`.

# %% [markdown]
# ### 1.4
#
# Interpret the slope for `availability` after adjusting for `safety`.

# %% [markdown]
# ### 1.5
# Fit a model explaining the outcome variable `affordability` and the predictor variable `availability`,  `safety`, and `resilience`.

# %% [markdown]
# ### 1.6
#
# Interpret the slope for `availability` adjusting for `safety` and `resilience`.

# %% [markdown]
# ### 1.7
#
# How does the slope change for `availability` for the different types of models.

# %% [markdown]
# ## Problem 2
#
# The `email` data set contains information of 3921 incoming emails from 2012. We are interested in modeling the outcome `spam` (spam email status) with the predictors `to_multiple` (if multiple recipients recieved the email), `image` (number of images in email), `winner` (whether the word "winner" appears in the message), and inherit (the number of times "inherit" is in the message).

# %% [markdown]
# ### 2.1
#
# Fit model explaining the outcome variable `spam` with the predictor variable `winner`. Write the equation of the model.

# %% [markdown]
# ## 2.2
#
# Interpret the slopes related to the variable `winner` based on the model.

# %% [markdown]
# ### 2.3
#
# Fit model explaining the outcome variable `spam` with the predictor variables `winner` and `to_multiple`. Write the equation of the model.

# %% [markdown]
# ## 2.4
#
# Interpret the slopes related to the variable `winner`, adjusting for `to_multipe`, based on the model.

# %% [markdown]
# ### 2.5
#
# Fit model explaining the outcome variable `spam` with the predictor variables `image`, `winner` and `to_multiple`. Write the equation of the model.

# %% [markdown]
# ## 2.6
#
# Interpret the slopes related to the variable `winner`, adjusting for `to_multipe` and `image`, based on the model.

# %% [markdown]
# ### 2.7
#
# How does the slope change for `winner` for the different types of models.
