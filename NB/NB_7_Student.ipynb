# %% [markdown]
# # NB 7: Modeling Premature Infants
#
# *Modified from Data Science in a Box*

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)

# %% [markdown]
# In 2004, the state of North Carolina released a large data set containing information on births recorded in this state.
# This data set is useful to researchers studying the relation between habits and practices of expectant mothers and the birth of their children.
# We will work with a random sample of observations from this data set.

# %% [markdown]
# ## Data
#
# The data can be found in the **openintro** package, and it's called `ncbirths`. You can find out more about the dataset by inspecting its documentation, which you can access by running `?ncbirths` in the code cell. You can also find this information [here](https://www.openintro.org/data/index.php?data=ncbirths). **The ouctome variable of interest is `premie`.**

# %% [markdown]
# ## Part 1: Premature vs. Number of Visits
#
# Consider the possible relationship between a number of doctor visits (`visits`) and if an infant is premature.

# %% [markdown]
# 1.  Find the descriptive statistics and visualize the data for the both the outcome of variable of interest `premie` and the predictor variable `visits`.

# %% [markdown]
# 2. Describe the distribution for both the outcome of variable of interest `premie` and the predictor variable `visits`.

# %% [markdown]
# 3. Construct a logistic regression model for the outcome of variable of interest `premie` and the predictor variable `visits`. Make sure you write the equation of the model.

# %% [markdown]
# 4. Interpret the coefficient for the predictor variable `visits`.

# %% [markdown]
# 5. Predict the probability of having a premature infant when the number of visits is 5.

# %% [markdown]
# 6. Predict the probability of having a premature infant when the number of visits is 10.

# %% [markdown]
# 7. Predict the probability of having a premature infant when the number of visits is 15.

# %% [markdown]
# 8. Based on problems 5, 6, and 7, do the results agree with the results from problem 4?

# %% [markdown]
# ## Part 2: Premature vs. Mother's Age
#
# Consider the possible relationship between mother's age (`mage`) and if an infant is premature.

# %% [markdown]
# 1.  Find the descriptive statistics and visualize the data for the both the outcome of variable of interest `premie` and the predictor variable `mage`.

# %% [markdown]
# 2. Describe the distribution for both the outcome of variable of interest `premie` and the predictor variable `mage`.

# %% [markdown]
# 3. Construct a logistic regression model for the outcome of variable of interest `premie` and the predictor variable `mage`. Make sure you write the equation of the model.

# %% [markdown]
# 4. Interpret the coefficient for the predictor variable `mage`.

# %% [markdown]
# 5. Predict the probability of having a premature infant when the mother's age is 20.

# %% [markdown]
# 6. Predict the probability of having a premature infant when the mother's age is 30.

# %% [markdown]
# 7. Predict the probability of having a premature infant when the mother's age is 40.

# %% [markdown]
# 8. Based on problems 5, 6, and 7, do the results agree with the results from problem 4?
