# %% [markdown]
# # NB 2: Measuring Shape Launches
# Adapted from Coursekata

# %% [markdown]
# Run the code below by clicking on the cell and pressing the left arrow sign or click `Shift+Enter` on the keyboard. This will install an R package called `rcistats` that contains helper functions to make your programming lives easier. It will take Colab approximately a minute. Afterwards, you will ask R to load the `rcistats` and `tidyverse` package. This is done using the library function like `library(rcistats)`.

# %%
install.packages("rcistats",
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)

# %% [markdown]
# ## 1.0 - How do we get data?
# We use data to try and understand all kinds of things: climate change, poverty, politics, psychology, health, etc. But that means we need to measure all kinds of things that are hard to measure. How do we measure how smart, happy, or healthy someone is? How powerful, free, or secure a country is? Once we get that data, we want to use data science to figure out whether this stuff changes, improves, differs across people, or predicts some future outcome, and much more.
#
# But it all starts with figuring out measurement -- how would we know *how much* of something exists? How would we know how that thing varies across people, animals, families, companies, countries?
#
# Let’s start by measuring something easy. The distance traveled by shapes!

# %% [markdown]
# 1.1 Create a group up to 5. Write the first and last name of each member in your group:

# %% [markdown]
# 1.2 The group member with the smallest hand, go get a handful of shapes from the instructor.

# %% [markdown]
# 1.3 Have a group member create a google sheet, and share it with each other. Write down the shareable link below:

# %% [markdown]
# 1.4 Begin recording different attributes of each shape in the google sheet. Use a tabular format as discussed in class.

# %% [markdown]
# 1.5 Before you begin launching, makes some predictions on which characteristics will be the farthest.

# %% [markdown]
# ## 2.0 - Launch some shapes
#
# Try a few shape launches.

# %% [markdown]
# 2.1 - Now that you’ve tried a few launches, what are some things that seem to affect how far the shapes go?
# Where it is loaded on catapult
# whether it is standing up or lying down?

# %% [markdown]
# 2.2 - Write a set of instructions on how you will launch a shape below.

# %% [markdown]
# 2.3 - Write a set of instructions on how you will measure the distance of the launch below.

# %% [markdown]
# ## 3.0 - Measuring Launch Distances
# Each person is going to be measuring their launching distances with a measuring tool.

# %% [markdown]
# 3.1 - Launch 1 shape and measure the distance. Do any questions come up for you?

# %% [markdown]
# 3.2 - Record the distance on the google sheet.

# %% [markdown]
# 3.3 - Repeat the process until all the shapes are catapulted and measured.

# %% [markdown]
# ## 4.0 - Reducing Variability

# %% [markdown]
# 4.1 - What are some things you could do if you wanted to make these measurements more similar? That is, how can you reduce the variability in your measurements?

# %% [markdown]
# 4|.2 - Do you think we can completely eliminate the variability in measurement? Why or why not?

# %% [markdown]
# ## 5.0 Evaluating Data Table

# %% [markdown]
# 5.1 - Let’s see if we have put the data into the spreadsheet in a way that can be analyzed by R.  Does your data meet the definition of tidy data?
#
#
# As a reminder, here are the three principles of tidy data:
#
# - Each column is a variable
# - Each row is an observation (also called a case, research unit, or an object; all these words mean the same thing)
# - Each type of observation is kept in a different table

# %% [markdown]
# ## 6.0 - From spreadsheet to data frame

# %% [markdown]
# 6.1 Now let’s try to put this data in R.
#
# Go to File > Share > Publish To Web
#
# In the Pop up Window, change Web Page to .csv
#
# Copy Link

# %%
link <- "PASTE LINK HERE"
df <- read_csv(link)
df

# %% [markdown]
# **6.2** Describe what the code above does.

# %% [markdown]
# **6.3** Do you notice any issues? Are there things we should fix in the spreadsheet?

# %% [markdown]
# ## 7.0 - Exploring the data

# %% [markdown]
# 7.1 - Which of the variables might be important in launching the shape farther? Which of these variables probably has nothing to do with how far the shapes gets launched?

# %% [markdown]
# ## Submitting Labs
#
# At the end of lab, you will need to submit an assignment. You can submit this lab via Canvas and Google Assignments.
#
# Additionally it is good practive to download the file in case anything goes wrong. *File* > *Download* > * Download as ipynb*
