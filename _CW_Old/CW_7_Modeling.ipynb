# %% [markdown]
# # CW 7: Modeling

# %% [markdown]
# ## Run Initial R Code

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro", "carData"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)
library(survival)
library(carData)

veteran$death <- veteran$status
# Out:
# Installing packages into ‘/home/isaac/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘airports’, ‘cherryblossom’, ‘usdata’
# trying URL 'https://cloud.r-project.org/src/contrib/airports_0.1.0.tar.gz'
# trying URL 'https://cloud.r-project.org/src/contrib/cherryblossom_0.1.0.tar.gz'
# trying URL 'https://cloud.r-project.org/src/contrib/usdata_0.3.1.tar.gz'
# trying URL 'https://inqs909.r-universe.dev/src/contrib/sha256-754746545e81f11644c5796d37bb4bf47ed1dbd495d7bb93c4ac3778bdcde64f'
# trying URL 'https://cloud.r-project.org/src/contrib/openintro_2.5.0.tar.gz'
# trying URL 'https://cloud.r-project.org/src/contrib/carData_3.0-6.tar.gz'
# * installing *source* package ‘airports’ ...
# ** this is package ‘airports’ version ‘0.1.0’
# ** package ‘airports’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (airports)
# * installing *source* package ‘cherryblossom’ ...
# ** this is package ‘cherryblossom’ version ‘0.1.0’
# ** package ‘cherryblossom’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (cherryblossom)
# * installing *source* package ‘usdata’ ...
# ** this is package ‘usdata’ version ‘0.3.1’
# ** package ‘usdata’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (usdata)
# * installing *source* package ‘rcistats’ ...
# ** this is package ‘rcistats’ version ‘0.1.3’
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rcistats)
# * installing *source* package ‘carData’ ...
# ** this is package ‘carData’ version ‘3.0-6’
# ** package ‘carData’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** data
# *** moving datasets to lazyload DB
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (carData)
# * installing *source* package ‘openintro’ ...
# ** this is package ‘openintro’ version ‘2.5.0’
# ** package ‘openintro’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (openintro)
#
# The downloaded source packages are in
# 	‘/tmp/RtmphSfS5U/downloaded_packages’
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.2
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
# Loading required package: airports
# Loading required package: cherryblossom
# Loading required package: usdata
#
# Attaching package: ‘survival’
#
# The following object is masked from ‘package:openintro’:
#
#     transplant

# %% [markdown]
# ## Problem 1
#
# The `veteran` data set contains 9 variables of 137 patients related to the Veterans' Administration Lung Cancer study. Four variable of interest in the study are `age` (in years), `trt` (1 = "standard", 2 = "test"), `celltype` (1="squamos", 2 = "smallcell", 3 = "adeno", and 4 = "large"), and `karno` (Karnofsky Performance Score; 100 = good). The outcome of interest was `death` (0 = "alive", 1 = "dead")

# %% [markdown]
# ### 1.1
#
# Fit model explaining the outcome variable `death` with the predictor variables `age`, `trt`, `celltype`, and `karno`. Write the equation of the model.

# %% [markdown]
# ## 1.2
#
# What is the reference category used for the variable `celltype`?

# %% [markdown]
# ## 1.3
#
# Interpret the slopes related to the variable `celltype` based on the model found.

# %% [markdown]
# ## 1.4
#
# Predict the probability of observing death for an individual in `trt = 1`, `karno = 58`, 65 years old, and a "smallcell" cell type.

# %% [markdown]
# ## 1.5
#
# Predict the probability of observing death for an individual in `trt = 1`, `karno = 58`, 65 years old, and a "adeno" cell type.

# %% [markdown]
# ## 1.6
#
# What is the difference in probabilities of observing death for an individual with a "smallcell" versus "adeno" cell type, keeping other predictors constant (`trt = 1`, `karno = 58`, 65 years old)

# %% [markdown]
# ## Problem 2
#
# The `Ginzberg` data set contains 6 variables on 82 patients who are depressed. The outcome of interest is `depression` (larger number means more depressed). The predictors of interest are `simplicity` (larger means the subject views the world in black or white), and `fatalism` (larger number means the subject has more fatalistic view).

# %% [markdown]
# ## 2.1
#
# Fit a model explaining the outcome `depression` with the predictors `simplicity` and `fatalism`. Write the equation of the model.

# %% [markdown]
# ## 2.2
#
# Interpret the slopes for `simplicity` and `fatalism`.

# %% [markdown]
# ## 2.3
#
# Predict the depression score for someone who has a fatalistic score of 2 and simplicity score or 4.

# %% [markdown]
# ## Exit Ticket
#
# ### Today's Ideas
#
# In your own words, what were today's ideas.
#
# ### Confidence
#
# What in one topic you feel more confident in?
#
# ### Confusion
#
# What are you still confused on?
