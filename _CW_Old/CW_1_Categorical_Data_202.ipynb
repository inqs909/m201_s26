# %% [markdown]
# ## Classwork 1: Water Access
#
# Nounkeu et al. ([2022](https://doi.org/10.1371/journal.pwat.0000029)) studied water access for three rural communities in Cameroon. For your reference, use the [slides](https://www.inqs.info/m2012_f25/lectures/3#/title-slide) from the categorical data lecture.

# %% [markdown]
# ## Run Initial Code

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "SRMData"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(SRMData)


# Uncomment and run for categorical plots
csucistats::install_plots()
library(ggtricks)
library(ggmosaic)
library(waffle)

# Uncomment and run for themes
# csucistats::install_themes()
# library(ThemePark)
# library(ggthemes)

# %% [markdown]
# ## Part 1: Understanding the Data

# %% [markdown]
# ### 1.1 Abstract
#
# Take a moment to read the [abstract](https://doi.org/10.1371/journal.pwat.0000029). What are the main findings of the paper?

# %% [markdown]
# ### 1.2 Viewing the Data
#
# Use the `glimpse()` function to view the data.

# %% [markdown]
# ### 1.3 Understanding the Variables
#
# Take a look at the [help documentation](https://cran.r-project.org/web/packages/SRMData/refman/SRMData.html#WaterAccess). Learn about the variables.

# %% [markdown]
# ### 1.4
#
# Which categorical variables are you interested in learning more about?

# %% [markdown]
# ### 1.5
#
# Which categorical variables do you think are related with each other?

# %% [markdown]
# ## Part 2: Computing Frequencies
#
# Looking at the variables that you reported in 1.4 and 1.5, computing the frequencies and proportions. Write down the distribution of data based on the results.

# %% [markdown]
# ## Part 3: Visualizing Frequencies
#
# Looking at the variables that you reported in 1.4 and 1.5, visualize the distribution of a few variables. Write down the distribution of data based on the results.

# %% [markdown]
# ## Part 4: Understanding Bivariate Relationships
#
# Looking at the variables that you reported in 1.5, describe the relationship between the variables.

# %% [markdown]
# ## Part 5: Visualizing Bivariate Relationships
#
# Looking at the variables that you reported in 1.5, visualize the relationship between the variables.
