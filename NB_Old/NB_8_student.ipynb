# %% [markdown]
# # NB 8: Modeling

# %% [markdown]
# ## Run Initial R Code

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "kmed"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(kmed)

heart_data <- kmed::heart
heart_data$disease <- factor(ifelse(heart_data$class == 0, "No", "Yes"))
heart_data$sex <- factor(ifelse(heart_data$sex == TRUE, "Male", "Female"))
heart_data$cp <- factor(heart_data$cp)

# %% [markdown]
# ## Problem 1
#
# The `globalfood` data set contains 4 variables of 113 countries evaluating food insecurity in 2012. The outcome of interest is `affordability` (index of food affordability), and it will be explained by the predictors: `availability` (food availability index), `safety` (food quality and safety index), and `resilience` (natural resource and resilience index).

# %% [markdown]
# ### 1.1
#
# Fit a model explaining the outcome variable `affordability` and the predictor variable `availability`, `safety`, and `resilience`.

# %% [markdown]
# ### 1.2
#
# Interpret the slopes for `availability`, `safety`, and `resilience`.

# %% [markdown]
# ### 1.3
#
# Predict the affordability index for a country with an availability of 63, safety of 74, and resilience of 56.

# %% [markdown]
# ## Problem 2
#
# The `heart_data` data set contains 14 variables of 297 patients related to the heart disease diagnosis study. Four predictor variables of interest in the study are `age` (in years), `sex` ("Male" or "Female"), `cp` (chest pain types, 1="typical angina", 2 = "atypical angina", 3 = "non-anginal pain", and 4 = "asymptomatic"), and `chol` (cholesterol). The outcome of interest was `disease` (indicates if they have heart disease).

# %% [markdown]
# ### 2.1
#
# Fit model explaining the outcome variable `disease` with the predictor variables `age`, `sex`, `cp`, and `chol`. Write the equation of the model.

# %% [markdown]
# ## 2.2
#
# Interpret the slopes related to the variable `cp` based on the model found.

# %% [markdown]
# ## 2.3
#
# Interpret the slope for `chol`.

# %% [markdown]
# ## 2.4
#
# Predict the heart disease for an individual who is a 65 years old male, has `chol = 230`, and chest pain is atypical angina `cp = "2"`.

# %% [markdown]
# ## 2.5
#
# Predict the heart disease for an individual who is a 65 years old male, has `chol = 230`, and chest pain is asymptomatic `cp = "4"`.
