# %% [markdown]
# # NB 10: Modelling Premature Infants Part 2
#
# *Modified from Data Science in a Box*

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)

# %% [markdown]
# In 2004, the state of North Carolina released a large data set containing information on births recorded in this state.
# This data set is useful to researchers studying the relation between habits and practices of expectant mothers and the birth of their children.
# We will work with a random sample of observations from this data set.

# %% [markdown]
# ## Data
#
# The data can be found in the **openintro** package, and it's called `ncbirths`.
# Since the dataset is distributed with the package, we don't need to load it separately; it becomes available to us when we load the package.
# You can find out more about the dataset by inspecting its documentation, which you can access by running `?ncbirths` in the Console or using the Help menu in RStudio to search for `ncbirths`.
# You can also find this information [here](https://www.openintro.org/data/index.php?data=ncbirths).

# %% [markdown]
# ## Part 1: Modeling Premature Infants and Smoking Habit

# %% [markdown]
# 1. Use the logistic regression to model the outcome `premie` and `habit`.

# %% [markdown]
# 2. Interpret the Odds Ratio between `premie` and `habit`.

# %% [markdown]
# 3. Write the null and alternative hypothesis to determine if `premie` and `habit` are associated or random.

# %% [markdown]
# 4. Use the p-value approach to test the null and alternative hypothesis.

# %% [markdown]
# 5. Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## Part 2: Adjusting for Mother's Mature Status
#
# Now consider how Mother's Maturity affects the likelihood of seeing a premature infant.

# %% [markdown]
# 1. Use a logistic regression model to characterize the association between the outcome `premie` and predictors `habit` and `mature`.

# %% [markdown]
# 2. Interpret the odds ratio for `habit` and `premie`.

# %% [markdown]
# 3. Write the null and alternative hypothesis to determine if `premie` and `habit` are associated or random, after adjsuting for mother's mature status.

# %% [markdown]
# 4. Use the p-value approach to test the null and alternative hypothesis.

# %% [markdown]
# 5. Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## Part 3: Adjusting for the number of hospital visits
#
# Now consider how the number of hospital visits affects the likelihood of seeing a premature infant.

# %% [markdown]
# 1. Use a logistic regression model to characterize the association between the outcome `premie` and predictors `visits`, `habit` and `mature`.

# %% [markdown]
# 2. Interpret the odds ratio for `visits` and `premie`.

# %% [markdown]
# 3. Write the null and alternative hypothesis to determine if `premie` and `habit` are associated or random, after adjsuting for mother's mature status.

# %% [markdown]
# 4. Use the confidence interval approach to test the null and alternative hypothesis.

# %% [markdown]
# 5. Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## Part 4: Adjusting for the mother's age
#
# Now consider how the mother's age the likelihood of seeing a premature infant.

# %% [markdown]
# 1. Use a logistic regression model to characterize the association between the outcome `premie` and predictors `mage`, `visits`, `habit` and `mature`.

# %% [markdown]
# 2. Interpret the odds ratio for `mage` and `premie`.

# %% [markdown]
# 3. Interpret the odds ratio for `visits` and `premie`.

# %% [markdown]
# 4. Write the null and alternative hypothesis to determine if `premie` and `mage` are associated or random, after adjsuting for mother's mature status.

# %% [markdown]
# 5. Use the confidence interval approach to test the null and alternative hypothesis.

# %% [markdown]
# 6. Interpret and draw conclusions from the results that you found.

# %% [markdown]
# 7. Which predictor variable has the most significant effect on the likelihood of premature infants.
