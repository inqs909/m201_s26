# %% [markdown]
# # NB 9: Hypothesis Testing

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro", "carData"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)
library(carData)
library(broom)

# %% [markdown]
# ## 1.0 - Linear regression with a numerical predictor

# %% [markdown]
# 1.1 - Fit a linear model predict average professor evaluation `score` (outcome) by average beauty rating (`bty_avg`) from the `evals` data set.
#     Based on the regression output, write the linear model.

# %% [markdown]
# 1.2 - Interpret the slope of the linear model in context of the data.

# %% [markdown]
# 1.3 - Write the null and alternative hypothesis to determine if `bty_avg` and `score` are associated or random.

# %% [markdown]
# 1.4 Use the p-value approach to test the null and alternative hypothesis.

# %% [markdown]
# 1.5 Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## 2.0 - Logistic regression with a numerical predictor

# %% [markdown]
# 2.1 - Fit a logistic model to predict smoking habit `habit` (outcome) by mother's age (`mage`) from the `ncbirths` data set.
#     Based on the regression output, write the logistic model.

# %% [markdown]
# 2.2 - Interpret the slope of the logistic model in context of the data.

# %% [markdown]
# 2.3 - Write the null and alternative hypothesis to determine if `habit` and `mage` are associated or random.

# %% [markdown]
# 2.4 Use the p-value approach to test the null and alternative hypothesis.

# %% [markdown]
# 2.5 Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## 3.0

# %% [markdown]
# 3.1 - The `Ginzberg` data set contains 6 variables on 82 patients who are depressed. We want to model the relationship between `depression` (larger number means more depressed) and `simplicity` (larger means the subject views the world in black or white). Fit a model to predict `depression` by  `simplicity`. Write the model.

# %% [markdown]
# 3.2 - Interpret the slope of the model in context of the data.

# %% [markdown]
# 3.3 - Write the null and alternative hypothesis to determine if `depression` and `simplicity` are associated or random.

# %% [markdown]
# 3.4 Use the p-value approach to test the null and alternative hypothesis.

# %% [markdown]
# 3.5 Interpret and draw conclusions from the results that you found.

# %% [markdown]
# ## 4.0 Submit Notebook
#
# Submit the notebook to Canvas.
