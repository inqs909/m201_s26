# %% [markdown]
# # CW 7: Multivariable Regression

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "OncoDataSets"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(OncoDataSets)

insurance <- read.csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv")
leukemia <- LeukemiaRemission_df |> 
  mutate(
    relapse = ifelse(event == "Relapse", "Yes", "No"),
    sex = ifelse(sex == 1, "Male", "Female")
  )
# Out:
# Installing packages into ‘/home/isaac/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)
# trying URL 'https://inqs909.r-universe.dev/src/contrib/sha256-f3de21b68dc64798a0ed4f5bb223c573846ed8935fc7c8967813b8014dc2675a'
# trying URL 'https://cloud.r-project.org/src/contrib/OncoDataSets_0.1.0.tar.gz'
# * installing *source* package ‘rcistats’ ...
# ** this is package ‘rcistats’ version ‘0.1.4’
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rcistats)
# * installing *source* package ‘OncoDataSets’ ...
# ** this is package ‘OncoDataSets’ version ‘0.1.0’
# ** package ‘OncoDataSets’ successfully unpacked and MD5 sums checked
# ...

# %% [markdown]
# ## Problem 1: Leukemia Remission
#
# The `leukemia` contains information about remission for leukemia patients that were involved in a randomized-control trial.  We are modeling the outcome variable `relapse` (indicating that leukemia has returned) with the predictors `sex`, `wbc` (white blood cell count), and `grp` (treatment group).

# %% [markdown]
# 1. Obtain the descriptive statistics and visualize `relapse`.

# %% [markdown]
# 2. Obtain the descripitive statistics for the predictor variables.

# %% [markdown]
# 3. Fit a regression model to explain the outcome `relapse` by the predictor variable.

# %% [markdown]
# 4. Write the equation of the line.

# %% [markdown]
# 5. Interpret the coefficient for `grp`.

# %% [markdown]
# 6. Predict `remission` when `grp` is "6-MP", `sex` is "Male", and `wbc` is 3.67.

# %% [markdown]
# ## Problem 2: Insurance Claims
#
# The `insurance` data set contains information about medical charges. We are interested how `charges` (outcome) is explained by `age`, `sex`, `bmi`, `children`, `smoker`, and `region`.

# %% [markdown]
# 1. Obtain the descriptive statistics and visualize `charges`.

# %% [markdown]
# 2. Obtain the descripitive statistics for the predictor variables.

# %% [markdown]
# 3. Fit a regression model to explain the outcome `charges` by the predictor variable.

# %% [markdown]
# 4. Write the equation of the line.

# %% [markdown]
# 5. Interpret the coefficient for `age`.

# %% [markdown]
# 6. Predict `charges` for a non-smoking, 34 year old, female patient, who lives in the northeast, no children, and has a bmi of 29.

# %% [markdown]
# ## Exit Ticket
#
# ### Today's Ideas
#
# In your own words, what were today's ideas.
#
# ### Confidence
#
# What in one topic you feel more confident in?
#
# ### Confusion
#
# What are you still confused on?
