# %% [markdown]
# ## Classwork 2: Mr. TrashWheel
#
# [Mr. Trashwheel](https://www.youtube.com/watch?v=H84d8eyhfyY) is a machine designed to collect trash at the end of waterways found in Baltimore, Maryland. Using both solar and hrydro power, it collects tons of waste every single year. During certain times of the year, crewmembers collect a random sample and compute estimates of how much trash, and each type of trash, is being collected each day. These estimates are provided as data for us to analyze in the dataframe `trashwheel`.

# %%
# This code will load the R packages we will use
install.packages(c("rcistats"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)

trashwheel <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2024/2024-03-05/trashwheel.csv')

# %% [markdown]
# ## Part 1: Understanding the Data

# %% [markdown]
# ### 1.1 Viewing Data
#
# View the data set `trashwheel`

# %% [markdown]
# ### 1.2
#
# How many observations and variables are in the data set?

# %% [markdown]
# ### 1.3
#
# What type of trash is being collected?

# %% [markdown]
# ### 1.4
#
# Which variables are you interested in learning more about?

# %% [markdown]
# ### 1.5
#
# Analyze `Name` variable, which trashwheels are present?

# %% [markdown]
# ## Part 2: Computing Descriptive Statistics

# %% [markdown]
# ### 2.1 Central Tendency
#
# Compute different central tendency statistics on the variable `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 2.2 Variation/Variability
#
# Compute different variation statistics on the variable `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 2.3 Describing Variables
#
# Using the statistics you computed in 2.1 and 2.2, describe the distribution of the variables `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 2.4
#
# Obtain descriptive statistics for one variable specified in 1.4, describe the distribution.

# %% [markdown]
# ## Part 3: Visualizing Data

# %% [markdown]
# ### 3.1 Box Plots
#
# Create a box plot for the variables `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 3.2 Histograms
#
# Create a histogram for the variables `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 3.4 Density Plots
#
# Create a density plot for the variables `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 3.4 Describing Variables
#
#
# Using the visual plots, describe the variables `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 3.5
#
# Create a visual plot for one variable specified in 1.4, describe the distribution.

# %% [markdown]
# ## Part 4: Bivariate Plots

# %% [markdown]
# ### 4.1 Scaatter Plot
#
# Create a scatter plot between `PlasticBottles` and `PlasticBags`.

# %% [markdown]
# ### 4.2 Density Plots by Groups
#
# Create a density plot for `PlasticBottles` by `Name`.

# %% [markdown]
# ### 4.3 Line Plot
#
# Create a Line Plot between `Date` and `PlasticBottles` by `Name`.

# %% [markdown]
# ### 4.4
#
# Display a Bivariate Plot between 2 variables of interest from 1.4.

# %% [markdown]
# ## Part 5: Exit Ticket
#
# ### Today's Ideas
#
# In your own words, what were today's ideas.
#
# ### Confidence
#
# What is one topic you feel more confident in?
#
# ### Confusion
#
# What are you still confused on?
