# %% [markdown]
# # CW 10: Inference

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "SRMData", "GLMsData"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(SRMData)
library(GLMsData)
library(broom)
library(carData)

ca_housing <- read.csv("https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv")
data(germBin)

# %% [markdown]
# ## Problem 1: Extraversion and Neuroticism
#
# The `Cowles` data set contains information about undergraduate students and the Eysenck Personality inventory from a 1987 [study](https://bpspsychub.onlinelibrary.wiley.com/doi/abs/10.1111/j.2044-8309.1987.tb00769.x). We are interested in understanding the relationship between the outcome variable `neuroticism` (outcome; feeling negative; lower number means less negative) and `extraversion` (predictor; being outgoing, higher number means more outgoing). Is there a significant relationship between the outcome and predictor?

# %% [markdown]
# ## Problem 2: A Dogs Life
#
# The `DogsLife` data set contains information about different dog breeds lifespan. You can find more information about the data set [here](https://cran.r-project.org/web/packages/SRMData/refman/SRMData.html#DogsLife) and their reference paper [here](https://www.journals.uchicago.edu/doi/10.1086/724384). We are interested if there is a significant association between `Lifespan` (outcome) and  `LitterSize`.

# %% [markdown]
# ## Problem 3: Surviving the Titanic
#
# The `TitanicSurvival` data set contains information about passenger survival on the Titanic. The variable `survived` indicates whether the passenger survived (outcome variable). The predictor `age`  provides the age of the passenger. Is there a significant relationship between age and survival?

# %% [markdown]
# ## Exit Ticket
#
# ### Today's Ideas
#
# In your own words, what were today's ideas.
#
# ### Confidence
#
# What in one topic you feel more confident in?
#
# ### Confusion
#
# What are you still confused on?
