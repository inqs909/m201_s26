# %% [markdown]
# # CW 5: Logistic Regression

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)

# %% [markdown]
# ## Problem 1: Heart Transplant
#
# We are interested in learning about the survival rate among patients who recieved a heart transplant. The data (`heart_transplant`) is based on the Stanford University Heart Transplant study. More information about the data can be found [here](https://www.openintro.org/data/index.php?data=heart_transplant). We will primarily focusing on explaining our outcome `survived`.

# %% [markdown]
# ### Part A
#
# We are interested in analyzing the relationship between the outcome variable `survived` (survival status) and the predictor `age`. Describe the distribution of both variables.

# %% [markdown]
# ### Part B
#
# Fit a regression line between the outcome variable `survived` and `age`. Write out the equation of the model.

# %% [markdown]
# ### Part C
#
# What is the probability of smoking for individuals who are 50 years old of age?

# %% [markdown]
# ## Problem 2: Smoking Habits
#
# We are interested in understanding the factors that contributes to someone's likelihood of smoking. Using data from the UK (`smoking`), we will analyze the outcome variable `smoke` with several predictor variables. More information about the data can be found [here](https://www.openintro.org/data/index.php?data=smoking).

# %% [markdown]
# ### Part A
#
# We are interested in analyzing the relationship between the outcome variable `smoke` (smoking status) and predictor `age`. Describe the distribution of both variables.

# %% [markdown]
# ### Part B
#
# Fit a regression line between the outcome variable `smoke` and `age`. Write out the equation of the model.

# %% [markdown]
# ### Part C
#
# What is the probability of smoking for individuals who are 40 years old of age?

# %% [markdown]
# ## Exit Ticket
#
# ### Today's Ideas
#
# In your own words, what were today's ideas.
#
# ### Confidence
#
# What in one topic you feel more confident in?
#
# ### Confusion
#
# What are you still confused on?
